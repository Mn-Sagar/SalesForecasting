# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# %matplotlib inline

# %%
data_frame = pd.read_csv('/home/sagar/Desktop/Train1.csv')

# %%
data_frame.head(3)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
# 2           FDN15        17.50          Low Fat         0.016760         Meat
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228
# 2               Tier 1  Supermarket Type1          2097.2700

# %%
data_frame.shape
# Out:
# (8523, 12)

# %%
data_frame.tail(3)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8520           NCJ29        10.60          Low Fat         0.035186
# 8521           FDN46         7.21          Regular         0.145221
# 8522           DRG01        14.80          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700

# %%
data_frame.isnull().values.any()
# Out:
# True

# %%
plt.figure(figsize=(10,7))
sns.heatmap(data_frame.corr())

# %%
rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(10, 10))
corr = df.corr()
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_18de2f6a_820d_11e8_87a5_70188b6bf667row0_col0 {
#             background-color:  #023858;
#         }    #T_18de2f6a_820d_11e8_87a5_70188b6bf667row0_col1 {
#             background-color:  #69a5cc;
#         }    #T_18de2f6a_820d_11e8_87a5_70188b6bf667row0_col2 {
#             background-color:  #3f93c2;
#         }    #T_18de2f6a_820d_11e8_87a5_70188b6bf667row0_col3 {
#             background-color:  #2f8bbe;
#         }    #T_18de2f6a_820d_11e8_87a5_70188b6bf667row0_col4 {
#             background-color:  #91b5d6;
#         }    #T_18de2f6a_820d_11e8_87a5_70188b6bf667row0_col5 {
#             background-color:  #fff7fb;
#         }    #T_18de2f6a_820d_11e8_87a5_70188b6bf667row0_col6 {
#             background-color:  #fff7fb;
#         }    #T_18de2f6a_820d_11e8_87a5_70188b6bf667row0_col7 {
#             background-color:  #2987bc;
#         }    #T_18de2f6a_820d_11e8_87a5_70188b6bf667row0_col8 {
#             background-color:  #efe9f3;
# ...

# %%
def corr_heatmap(data_frame, size=11):
correlation = data_frame.corr()
#fig, heatmap = plt.subplots(figsize=(size, size))
heatmap.matshow(correlation)
plt.xticks(arange(len(correlation.columns)), correlation.columns)
plt.yticks(arange(len(correlation.columns)), correlation.columns)
plt.show()
# Out:
#   File "<ipython-input-71-c67035c6036d>", line 2
#     correlation = data_frame.corr()
#               ^
# IndentationError: expected an indented block
